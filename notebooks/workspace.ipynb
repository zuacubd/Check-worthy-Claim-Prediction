# %%
from datasets import list_datasets, load_dataset, list_metrics, load_metric, Features, Value, ClassLabel

features = Features({'id': Value('string'), 'speaker': Value('string'), 'text': Value('string'), 'label': Value('string')})

dataset = load_dataset('text', features=features,
                       data_files= {
                           'train': '/projets/sig/mullah/nlp/checkthat18/data/raw/task1_train/train_data.txt', 
                           'test': '/projets/sig/mullah/nlp/checkthat18/data/raw/task1_gold/English/task1-en-file5.txt'}
                      )

print (dataset['train']['text'])
# Out:
# Using custom data configuration default
# Reusing dataset text (/users/sig/mullah/.cache/huggingface/datasets/text/default-1b7b3e2bae3f1a1f/0.0.0/7c0f8af3178a6c694d530e71edd8f1ec1d7311867f8c29955898c29a0624adf5)
# ['1\tHOLT\tGood evening from Hofstra University in Hempstead, New York.\t0', '2\tHOLT\tI\'m Lester Holt, anchor of "NBC Nightly News."\t0', '3\tHOLT\tI want to welcome you to the first presidential debate.\t0', '4\tHOLT\tThe participants tonight are Donald Trump and Hillary Clinton.\t0', '5\tHOLT\tThis debate is sponsored by the Commission on Presidential Debates, a nonpartisan, nonprofit organization.\t0', "6\tHOLT\tThe commission drafted tonight's format, and the rules have been agreed to by the campaigns.\t0", '7\tHOLT\tThe 90-minute debate is divided into six segments, each 15 minutes long.\t0', "8\tHOLT\tWe'll explore three topic areas tonight: Achieving prosperity; America's direction; and securing America.\t0", '9\tHOLT\tAt the start of each segment, I will ask the same lead-off question to both candidates, and they will each have up to two minutes to respond.\t0', "10\tHOLT\tFrom that point until the end of the segment, we'll have an open discussion.\t0", '11\tHOLT\tThe questions are mine and have not been shared with the commission or the campaigns.\t0', '12\tHOLT\tThe audience here in the room has agreed to remain silent so that we can focus on what the candidates are saying.\t0', '13\tHOLT\tI will invite you to applaud, however, at this moment, as we welcome the candidates: Democratic nominee for president of the United States, Hillary Clinton, and Republican nominee for president of the United States, Donald J. Trump.\t0', '14\tSYSTEM\t(APPLAUSE)\t0', '15\tCLINTON\tHow are you, Donald?\t0', '16\tSYSTEM\t(APPLAUSE)\t0', '17\tHOLT\tGood luck to you.\t0', '18\tSYSTEM\t(APPLAUSE)\t0', "19\tHOLT\tWell, I don't expect us to cover all the issues of this campaign tonight, but I remind everyone, there are two more presidential debates scheduled.\t0", "20\tHOLT\tWe are going to focus on many of the issues that voters tell us are most important, and we're going to press for specifics.\t0", '21\tHOLT\tI am honored to have this role, but this evening belongs to the candidates and, just as important, to the American people.\t0', '22\tHOLT\tCandidates, we look forward to hearing you articulate your policies and your positions, as well as your visions and your values.\t0', "23\tHOLT\tSo, let's begin.\t0", '24\tHOLT\tWe\'re calling this opening segment "Achieving Prosperity."\t0', '25\tHOLT\tAnd central to that is jobs.\t0', '26\tHOLT\tThere are two economic realities in America today.\t0', "27\tHOLT\tThere's been a record six straight years of job growth, and new census numbers show incomes have increased at a record rate after years of stagnation.\t0", '28\tHOLT\tHowever, income inequality remains significant, and nearly half of Americans are living paycheck to paycheck.\t0', '29\tHOLT\tBeginning with you, Secretary Clinton, why are you a better choice than your opponent to create the kinds of jobs that will put more money into the pockets of American works?\t0', '30\tCLINTON\tWell, thank you, Lester, and thanks to Hofstra for hosting us.\t0', "31\tCLINTON\tThe central question in this election is really what kind of country we want to be and what kind of future we'll build together.\t0", "32\tCLINTON\tToday is my granddaughter's second birthday, so I think about this a lot.\t0", '33\tCLINTON\tFirst, we have to build an economy that works for everyone, not just those at the top.\t0', '34\tCLINTON\tThat means we need new jobs, good jobs, with rising incomes.\t0', '35\tCLINTON\tI want us to invest in you.\t0', '36\tCLINTON\tI want us to invest in your future.\t0', '37\tCLINTON\tThat means jobs in infrastructure, in advanced manufacturing, innovation and technology, clean, renewable energy, and small business, because most of the new jobs will come from small business.\t0', '38\tCLINTON\tWe also have to make the economy fairer.\t0', "39\tCLINTON\tThat starts with raising the national minimum wage and also guarantee, finally, equal pay for women's work.\t0", '40\tCLINTON\tI also want to see more companies do profit-sharing.\t0', '41\ ...
